# %% [markdown]
# # Airline Passenger Satisfaction Survey Dataset
#
# ## Context
# This dataset contains an airline passenger satisfaction survey. The goal is to understand the factors that contribute to passenger satisfaction and predict whether a passenger is satisfied or dissatisfied.
#
# ## Content
#
# - **Gender**: Gender of the passengers (Female, Male)
# - **Customer Type**: The customer type (Loyal customer, Disloyal customer)
# - **Age**: The actual age of the passengers
# - **Type of Travel**: Purpose of the flight of the passengers (Personal Travel, Business Travel)
# - **Class**: Travel class in the plane of the passengers (Business, Eco, Eco Plus)
# - **Flight Distance**: The flight distance of this journey
# - **Inflight Wifi Service**: Satisfaction level of the inflight wifi service (0: Not Applicable; 1-5)
# - **Departure/Arrival Time Convenient**: Satisfaction level of Departure/Arrival time convenience
# - **Ease of Online Booking**: Satisfaction level of online booking
# - **Gate Location**: Satisfaction level of gate location
# - **Food and Drink**: Satisfaction level of food and drink
# - **Online Boarding**: Satisfaction level of online boarding
# - **Seat Comfort**: Satisfaction level of seat comfort
# - **Inflight Entertainment**: Satisfaction level of inflight entertainment
# - **On-board Service**: Satisfaction level of on-board service
# - **Leg Room Service**: Satisfaction level of leg room service
# - **Baggage Handling**: Satisfaction level of baggage handling
# - **Check-in Service**: Satisfaction level of check-in service
# - **Inflight Service**: Satisfaction level of inflight service
# - **Cleanliness**: Satisfaction level of cleanliness
# - **Departure Delay in Minutes**: Minutes delayed at departure
# - **Arrival Delay in Minutes**: Minutes delayed at arrival
# - **Satisfaction**: Airline satisfaction level (Satisfaction, Neutral, or Dissatisfaction)

# %% [markdown]
# ## Importing Necessay Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.shape, test. shape
# Out:
# ((103904, 25), (25976, 25))

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df = pd.concat([train, test])
df.shape
# Out:
# (129880, 25)

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace = True)

# %%
df.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129880 entries, 0 to 25975
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Inflight wifi service              129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Ease of Online booking             129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# ...

# %%
df = df.dropna()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    73225
# satisfied                  56262
# Name: count, dtype: int64

# %%
category_col = []
for col in df.columns:
    if df[col].dtype == object and col != 'satisfaction':
        category_col.append(col)

# %%
category_col
# Out:
# ['Gender', 'Customer Type', 'Type of Travel', 'Class']

# %%
plt.figure(figsize=(12,12))
for i,col in enumerate(category_col):
    plt.subplot(2,2,i+1)
    plt.title(f'{col} distribution w.r.t. satisfaction')
    sns.countplot(data = df, x= col, hue='satisfaction')

# %% [markdown]
# Observation:
# - percentage of females neutral or dissatisfied is more then in case of males
# - disloyal customers are generally more neutral or dissatisified
# - people  travelling related to business are more satisfied than the ones travelling for personal reasons
# - people travelling in business class are more satisified rather than the ones travelling in economy class

# %%
ordinal_col = ['Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 
'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling',
'Checkin service', 'Inflight service', 'Cleanliness']

# %%
len(ordinal_col)
# Out:
# 14

# %%
plt.figure(figsize=(12,35))
for i,col in enumerate(ordinal_col):
    plt.subplot(7,2,i+1)
    plt.title(f'{col} distribution w.r.t. satisfaction')
    sns.countplot(data = df, x= col, hue='satisfaction')

# %% [markdown]
# Observation:
# - more the people are satisfied with the wifi service more is the overall satisfaction of customers
# - departure/arrival time isn't much contributing
# - more the ease of online booking more is the satisfaction of the customer
# - gate locationisn't affecting the overall satisfaction
# - the good the food and drink distribution is more the number of satisfied customers, although the the number of neutral or dissatisfied customers doesn't decrease that much
# - online boarding is the most affecting feature, customers prefer online boarding to avoid long queue, so satisfied customers increase if they are offered online boarding option
# - seat comfort has the same effect as the online boarding, more the seat comfort more satisfied is the customer
# - in-flight entertainment, on board service, leg room service, baggage handling, inflight service also contributes in satisfying more customers
# - customers like cleanliness, more the cleanliness more is the satified customers although the number of neutral or dissatisfied customers doesn't decrease that much
#
# So we can conclude that more services provided for customers the more is the chances of them being satisfied

# %%
sns.histplot(data=df, x='Age', hue='satisfaction')
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# Observation:
# - customers in the age range 10-40 and 60-80 are more probably neutral or dissatisfied
# - customers in the range 40-60 are generally satisfied

# %%
plt.figure(figsize=(10,10))
for i,col in enumerate(category_col):
    plt.subplot(2,2,i+1)
    sns.histplot(data=df, x='Age', hue=col)
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# Observation:
# - Almost equal distribution of gender in all ages
# - disloyal customers are mostly the people in their 20s (maybe they are trying many options)
# - customers have a uniform distribution doing personal travel
# - customers within the age range 30-60 prefer business class and others prefer eco class
# - eco plus have the same demand among all ages

# %%
sns.histplot(data=df, x='Flight Distance', hue='satisfaction')
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
[col for col in df.columns if col not in ordinal_col and col not in category_col]
# Out:
# ['id',
#  'Age',
#  'Flight Distance',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'satisfaction']

# %%
df['Departure Delay in Minutes'].describe()
# Out:
# count    129487.000000
# mean         14.643385
# std          37.932867
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          12.000000
# max        1592.000000
# Name: Departure Delay in Minutes, dtype: float64

# %%
df['Arrival Delay in Minutes'].describe()
# Out:
# count    129487.000000
# mean         15.091129
# std          38.465650
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1584.000000
# Name: Arrival Delay in Minutes, dtype: float64

# %% [markdown]
# ## Data Preprocessing

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
df1['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    73225
# satisfied                  56262
# Name: count, dtype: int64

# %%
gender_mapped = {'Male':1, 'Female':0}
customer_type_mapped = {'Loyal Customer':1, 'disloyal Customer':0}
travel_type_mapped = {'Business travel':1, 'Personal Travel':0}
class_mapped = {'Eco':0, 'Eco Plus':1, 'Business':2}
satisfaction_mapped = {'neutral or dissatisfied':0, 'satisfied':1}

# %%
df1['Gender'] = df1['Gender'].map(gender_mapped)
df1['Customer Type'] = df1['Customer Type'].map(customer_type_mapped)
df1['Type of Travel'] = df1['Type of Travel'].map(travel_type_mapped)
df1['Class'] = df1['Class'].map(class_mapped)
df1['satisfaction'] = df1['satisfaction'].map(satisfaction_mapped)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129487 entries, 0 to 25975
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129487 non-null  int64
#  1   Gender                             129487 non-null  int64
#  2   Customer Type                      129487 non-null  int64
#  3   Age                                129487 non-null  int64
#  4   Type of Travel                     129487 non-null  int64
#  5   Class                              129487 non-null  int64
#  6   Flight Distance                    129487 non-null  int64
#  7   Inflight wifi service              129487 non-null  int64
#  8   Departure/Arrival time convenient  129487 non-null  int64
#  9   Ease of Online booking             129487 non-null  int64
#  10  Gate location                      129487 non-null  int64
# ...

# %%
df1.describe()
# Out:
#                   id         Gender  Customer Type            Age  \
# count  129487.000000  129487.000000  129487.000000  129487.000000
# mean    64958.335169       0.492590       0.816862      39.428761
# std     37489.781165       0.499947       0.386781      15.117597
# min         1.000000       0.000000       0.000000       7.000000
# 25%     32494.500000       0.000000       1.000000      27.000000
# 50%     64972.000000       0.000000       1.000000      40.000000
# 75%     97415.500000       1.000000       1.000000      51.000000
# max    129880.000000       1.000000       1.000000      85.000000
#
#        Type of Travel          Class  Flight Distance  Inflight wifi service  \
# count   129487.000000  129487.000000    129487.000000          129487.000000
# mean         0.690764       1.029910      1190.210662               2.728544
# std          0.462180       0.962638       997.560954               1.329235
# ...

# %%
plt.figure(figsize=(18,18))
sns.heatmap(df1.corr(), annot=True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# ## Model Building

# %%
X = df1.drop('satisfaction', axis=1)
y = df1['satisfaction']

# %% [markdown]
# #### Scaling data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)

# %% [markdown]
# #### Splittin Data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((103589, 23), (25898, 23))

# %% [markdown]
# #### Importing Libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score

# %% [markdown]
# #### Logistic Regression

# %%
lgr = LogisticRegression()
lgr.fit(x_train, y_train)
y_pred_lgr = lgr.predict(x_test)
print("Accuracy Score:", accuracy_score(y_test, y_pred_lgr))
sns.heatmap(confusion_matrix(y_test, y_pred_lgr), annot=True, fmt='.0f')
print(classification_report(y_test,y_pred_lgr))
# Out:
# Accuracy Score: 0.8739671017066954
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     14631
#            1       0.87      0.84      0.85     11267
#
#     accuracy                           0.87     25898
#    macro avg       0.87      0.87      0.87     25898
# weighted avg       0.87      0.87      0.87     25898

# %% [markdown]
# #### Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
y_pred_dt = dt.predict(x_test)
print("Accuracy Score:", accuracy_score(y_test, y_pred_dt))
sns.heatmap(confusion_matrix(y_test, y_pred_dt), annot=True, fmt='.0f')
print(classification_report(y_test,y_pred_dt))
# Out:
# Accuracy Score: 0.9457487064638196
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     14631
#            1       0.94      0.94      0.94     11267
#
#     accuracy                           0.95     25898
#    macro avg       0.94      0.95      0.94     25898
# weighted avg       0.95      0.95      0.95     25898

# %% [markdown]
# #### Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
y_pred_rf = dt.predict(x_test)
print("Accuracy Score:", accuracy_score(y_test, y_pred_rf))
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt='.0f')
print(classification_report(y_test,y_pred_rf))
# Out:
# Accuracy Score: 0.9457487064638196
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     14631
#            1       0.94      0.94      0.94     11267
#
#     accuracy                           0.95     25898
#    macro avg       0.94      0.95      0.94     25898
# weighted avg       0.95      0.95      0.95     25898

# %% [markdown]
# #### SVM

# %%
svm = SVC()
svm.fit(x_train, y_train)
y_pred_svm = svm.predict(x_test)
print("Accuracy Score:", accuracy_score(y_test, y_pred_svm))
sns.heatmap(confusion_matrix(y_test, y_pred_svm), annot=True, fmt='.0f')
print(classification_report(y_test,y_pred_svm))
# Out:
# Accuracy Score: 0.9572553865163334
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     14631
#            1       0.96      0.94      0.95     11267
#
#     accuracy                           0.96     25898
#    macro avg       0.96      0.96      0.96     25898
# weighted avg       0.96      0.96      0.96     25898

# %% [markdown]
# #### MUlti Layer Perceptron

# %%
mlpc = MLPClassifier()
mlpc.fit(x_train, y_train)
y_pred_mlpc = mlpc.predict(x_test)
print("Accuracy Score:", accuracy_score(y_test, y_pred_mlpc))
sns.heatmap(confusion_matrix(y_test, y_pred_mlpc), annot=True, fmt='.0f')
print(classification_report(y_test,y_pred_mlpc))
# Out:
# Accuracy Score: 0.9598810718974439
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     14631
#            1       0.96      0.94      0.95     11267
#
#     accuracy                           0.96     25898
#    macro avg       0.96      0.96      0.96     25898
# weighted avg       0.96      0.96      0.96     25898

# %% [markdown]
# ## Results

# %%
f1_scores = []
y_pred = [y_pred_lgr, y_pred_rf, y_pred_dt, y_pred_svm, y_pred_mlpc]
for pred in y_pred:
    f1_scores.append(f1_score(y_test,pred, average=None))

# %%
f1_scores
# Out:
# [array([0.88987854, 0.85268099]),
#  array([0.9518918 , 0.93780709]),
#  array([0.9518918 , 0.93780709]),
#  array([0.96252919, 0.9502539 ]),
#  array([0.9647474 , 0.95345608])]

# %%
accuracy_scores = []
y_pred = [y_pred_lgr, y_pred_rf, y_pred_dt, y_pred_svm, y_pred_mlpc]
for pred in y_pred:
    accuracy_scores.append(accuracy_score(y_test,pred))

# %%
accuracy_scores
# Out:
# [0.8739671017066954,
#  0.9457487064638196,
#  0.9457487064638196,
#  0.9572553865163334,
#  0.9598810718974439]

# %%
models = ['Logistic Regression', 'Random Forest', 'Decision Tree', 'SVM', 'MUlti Layer Perceptron']

# %%
plt.figure(figsize=(10, 8))
ax = sns.barplot(x=models, y=accuracy_scores, palette='Blues')

# Add value annotations on top of each bar
for i, score in enumerate(accuracy_scores):
    ax.text(i, score + 0.01, f'{score:.2f}', ha='center', va='bottom', fontsize=12)

# Set the title and axis labels
plt.title('Model Accuracy Comparison', fontsize=16)
plt.xlabel('Models', fontsize=14)
plt.ylabel('Accuracy Score', fontsize=14)

# Rotate x-axis labels if needed (e.g., if model names are long)
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
# Number of models
n_models = len(f1_scores)

# Set up bar positions
ind = range(n_models)  # the x locations for the groups
width = 0.35  # the width of the bars

colors = ['#A4C8FF','#3F9BFF']

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Bars for each class (Class 1 and Class 2)
bars1 = ax.bar([i - width / 2 for i in ind], [f1_scores[i][0] for i in ind], width, label='neutal or dissatisfied', color=colors[0])
bars2 = ax.bar([i + width / 2 for i in ind], [f1_scores[i][1] for i in ind], width, label='satisfied', color=colors[1])

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('Model')
ax.set_ylabel('F1 Score')
ax.set_title('F1 Score Comparison across 5 Models')
ax.set_xticks(ind)
ax.set_xticklabels(models)
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()
